# %%
import folium
way1=[[16.7850, 80.8488],[16.7107, 81.0952],[16.8073, 81.5316],[16.8978, 81.6748], [17.0005, 81.8040],[16.9341, 81.9555],[17.0453, 82.1691],[17.2789, 82.4013],[17.3573, 82.5443],[17.403335929714842, 82.53201430608537],[17.425924106675346, 82.55357750665725],[17.477191983892002, 82.57314721107619],[17.512883729776725, 82.579273376475]]
way2=[[16.7850, 80.8488],[16.7107, 81.0952],[16.8073, 81.5316],[16.8978, 81.6748], [17.0005, 81.8040],[16.9341, 81.9555],[17.0453, 82.1691],[17.2789, 82.4013],[17.3573, 82.5443],[17.4324, 82.5226],[17.4952, 82.5524],[17.512883729776725, 82.579273376475]]
from branca.element import Figure
fig=Figure(width=550,height=350)
f1=folium.FeatureGroup("Vehicle 1")
f2=folium.FeatureGroup("Vehicle 2")
map=folium.Map(location=[16.780001,80.849998],tiles='cartodbpositron')
line_1=folium.vector_layers.PolyLine(way1,popup='<b>Path of Vehicle_1</b>',tooltip='Vehicle_1',color='blue',weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(way2,popup='<b>Path of Vehicle_2</b>',tooltip='Vehicle_2',color='red',weight=10).add_to(f2)
f1.add_to(map)
f2.add_to(map)
folium.Marker(location=[17.2827, 82.4010],popup='TEMPLE',tooltip='Click here to see Annavaram temple',icon=folium.Icon(color='yellow',prefix='fa',icon='bell')).add_to(map)
folium.Marker(location=[17.004393,81.783325],popup='<strong>Marker3</strong>',tooltip='<strong>Rajahmundry bridge</strong>',icon=folium.Icon(color='green',prefix='glyphicon',icon='tours')).add_to(map)
folium.Marker(location=[17.3550, 82.5404],popup='<h3 style="color:green;">Marker2</h3>',tooltip='<strong>Tuni Government Hospital</strong>',icon=folium.Icon(color='purple',prefix='fa',icon='anchor')).add_to(map)
folium.Marker(location=[16.7850, 80.8488],popup='Starting point',tooltip='Nuzvidu',icon=folium.Icon(color='blue',prefix='fa',icon='university')).add_to(map)
folium.Marker(location=[17.512883729776725, 82.579273376475],popup='Destination',tooltip='P.Kothapalli',icon=folium.Icon(color='blue',prefix='fa',icon='home')).add_to(map)
folium.LayerControl().add_to(map)
map
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: color argument of Icon should be one of: {'white', 'orange', 'pink', 'purple', 'beige', 'blue', 'cadetblue', 'lightgray', 'lightred', 'darkblue', 'green', 'black', 'darkpurple', 'lightgreen', 'lightblue', 'gray', 'red', 'darkred', 'darkgreen'}.
#   del sys.path[0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
# ...
